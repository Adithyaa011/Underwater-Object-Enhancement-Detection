# %% [markdown]
# Diffusion Model

# %%
# !/opt/bin/nvidia-smi
# Out:
# Thu Apr 25 10:13:55 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   43C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %% [markdown]
# Clone the code

# %%
# !git clone https://github.com/Adithyaa011/ImageRestoration.git
# Out:
# Cloning into 'ImageRestoration'...
# remote: Enumerating objects: 128, done.
# remote: Counting objects: 100% (128/128), done.
# remote: Compressing objects: 100% (92/92), done.
# remote: Total 128 (delta 40), reused 56 (delta 7), pack-reused 0
# Receiving objects: 100% (128/128), 2.30 MiB | 46.24 MiB/s, done.
# Resolving deltas: 100% (40/40), done.

# %%
# !mkdir /content/ImageRestoration/hq_demo/data/pretrained

# %% [markdown]
# Environment setup

# %%
# !pip install numpy torch blobfile tqdm pyYaml pillow
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.7/73.7 kB 2.5 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# ...

# %% [markdown]
# # **DDPM for images**

# %%
# %cd /content/ImageRestoration/hq_demo/data/pretrained
# Out:
# /content/ImageRestoration/hq_demo/data/pretrained

# %%
# !gdown https://drive.google.com/uc?id=1norNWWGYP3EZ_o05DmoW1ryKuKMmhlCX
# Out:
# Failed to retrieve file url:
#
# 	Too many users have viewed or downloaded this file recently. Please
# 	try accessing the file again later. If the file you are trying to
# 	access is particularly large or is shared with many people, it may
# 	take up to 24 hours to be able to view or download the file. If you
# 	still can't access a file after 24 hours, contact your domain
# 	administrator.
#
# You may still be able to access the file from the browser:
#
# 	https://drive.google.com/uc?id=1norNWWGYP3EZ_o05DmoW1ryKuKMmhlCX
#
# but Gdown can't. Please check connections and permissions.

# %% [markdown]
# Run the following code:

# %%
# %cd /content/ImageRestoration/hq_demo
# Out:
# /content/ImageRestoration/hq_demo

# %%
# !python main.py --config confs/face256.yml --path_y data/datasets/gts/face/0.png --deg "inpainting" -i face
# Out:
# Start face256
# Traceback (most recent call last):
#   File "/content/ImageRestoration/hq_demo/main.py", line 194, in <module>
#     main(conf_arg, args)
#   File "/content/ImageRestoration/hq_demo/main.py", line 43, in main
#     dist_util.load_state_dict(os.path.expanduser(
#   File "/content/ImageRestoration/hq_demo/guided_diffusion/dist_util.py", line 21, in load_state_dict
#     with bf.BlobFile(path, "rb") as f:
#   File "/usr/local/lib/python3.10/dist-packages/blobfile/_ops.py", line 358, in BlobFile
#     return default_context.BlobFile(
#   File "/usr/local/lib/python3.10/dist-packages/blobfile/_context.py", line 869, in BlobFile
#     f = io.FileIO(path, mode=mode)
# FileNotFoundError: [Errno 2] No such file or directory: './data/pretrained/celeba256_250000.pt'

# %% [markdown]
# Show the input image

# %%
from PIL import Image
img_Apy = Image.open('/content/ImageRestoration/hq_demo/results/face/Apy/00000.png')
img_Apy
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-601479eeb99f> in <cell line: 2>()
#       1 from PIL import Image
# ----> 2 img_Apy = Image.open('/content/ImageRestoration/hq_demo/results/face/Apy/00000.png')
#       3 img_Apy
#
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py in open(fp, mode, formats)
#    3225
#    3226     if filename:
# -> 3227         fp = builtins.open(filename, "rb")
#    3228         exclusive_fp = True
#    3229
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/ImageRestoration/hq_demo/results/face/Apy/00000.png'

# %% [markdown]
# Show the result restored by DDNM

# %%
from PIL import Image
img = Image.open('/content/ImageRestoration/hq_demo/results/face/final/00000.png')
img
